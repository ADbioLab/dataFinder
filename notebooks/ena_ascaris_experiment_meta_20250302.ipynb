# %% [markdown]
# # Analyse the ENA Records
#
# Records retrieved from ENA on 2-Mar-2025 using the broad search term 'ascaris'.
#
# All experiments were extracted to xml and saved under `data/ENA_ascaris_experiments/ena_sra-experiment_20250302-1102.xml`

# %%
import time
import xml.etree.ElementTree as ET
from collections import OrderedDict

import pandas as pd

# %%
# helper functions from sra_src/parser.py modified for the ENA experiment xml
def return_text(element: ET.Element) -> str | None:
    return None if element == None else element.text


def extract_data(record: ET.Element) -> list[OrderedDict]:
    """Extracts the important information from a EXPERIMENT_PACKAGE record.

    Args:
        record (ET.Element): xml element of the EXPERIMENT_PACKAGE record

    Returns:
        list[dict]: list of all the run records extracted into a dict.
    """
    data_rec = OrderedDict()
    data_rec["Experiment"] = record.attrib.get("accession")

    # library info
    lib_descriptor = record.find("DESIGN/LIBRARY_DESCRIPTOR")
    data_rec["LibraryStrategy"] = return_text(lib_descriptor.find("LIBRARY_STRATEGY"))
    data_rec["LibrarySelection"] = return_text(lib_descriptor.find("LIBRARY_SELECTION"))
    data_rec["LibrarySource"] = return_text(lib_descriptor.find("LIBRARY_SOURCE"))
    data_rec["LibraryLayout"] = [i.tag for i in lib_descriptor.find("LIBRARY_LAYOUT")][
        0
    ]
    data_rec["LibraryProtocol"] = return_text(
        lib_descriptor.find("LIBRARY_CONSTRUCTION_PROTOCOL")
    )

    # sequencer
    platform = record.find("PLATFORM")
    data_rec["Sequencer"] = [
        [return_text(gc) for gc in child][0] for child in platform
    ][0]

    # study info
    data_rec["StudyId"] = return_text(record.find("STUDY_REF/IDENTIFIERS/PRIMARY_ID"))

    # sample info
    sample_block = record.find("DESIGN/SAMPLE_DESCRIPTOR")
    data_rec["SampleId"] = sample_block.attrib.get("accession")
    data_rec["BioSample"] = return_text(sample_block.find("IDENTIFIERS/EXTERNAL_ID"))
    return data_rec

# %%
# data source as mentioned in first
ena_xmls = "../data/ENA_ascaris_metadata/ena_sra-experiment_20250302-1102.xml"

start_run = time.time()

record = []
count = 0
records = []

# parse each xml record of an experiment
with open(ena_xmls, "r") as handle:
    for line in handle.readlines():
        if (line := line.strip()) in [
            "<EXPERIMENT_SET>",
        ]:
            continue
        record.append(line)

        # find the end of the experiment package xml record
        if line == "</EXPERIMENT>":
            parsed_records = extract_data(ET.fromstringlist(record))
            record = []
            count += 1
            if count == 1:
                records.append(list(parsed_records.keys()))

            records.append([str(i) for _, i in parsed_records.items()])

            if count % 1000 == 0:
                print(f"{count} records parsed in {round(time.time()-start_run)}s")

    print(f"Run records parsed = {count}")
# Out:
# 1000 records parsed in 0s
# Run records parsed = 1172

# %%
df = pd.DataFrame.from_records(records[1:], columns=records[0])

# %%
df.columns
# Out:
# Index(['Experiment', 'LibraryStrategy', 'LibrarySelection', 'LibrarySource',
#        'LibraryLayout', 'LibraryProtocol', 'Sequencer', 'StudyId', 'SampleId',
#        'BioSample'],
#       dtype='object')

# %%
df["Sequencer"].value_counts()
# Out:
# Sequencer
# Illumina MiSeq                  747
# Illumina NovaSeq 6000           190
# Illumina HiSeq 2000             110
# Illumina Genome Analyzer         51
# Illumina Genome Analyzer II      26
# Illumina HiSeq 2500              20
# Illumina HiSeq 4000              18
# Illumina HiSeq 1000               6
# Illumina Genome Analyzer IIx      2
# 454 GS FLX Titanium               1
# Illumina HiSeq 3000               1
# Name: count, dtype: int64

# %%
df["LibrarySelection"].value_counts()
# Out:
# LibrarySelection
# PCR                   739
# size fractionation    188
# ChIP                   62
# RANDOM                 52
# unspecified            44
# cDNA                   40
# other                  40
# RT-PCR                  7
# Name: count, dtype: int64

# %%
# focus on the random library selection strategy
pd.crosstab(df["LibraryStrategy"], df["LibrarySelection"])
# Out:
# LibrarySelection  ChIP  PCR  RANDOM  RT-PCR  cDNA  other  size fractionation  \
# LibraryStrategy
# AMPLICON             0  739       0       0     0      0                   0
# ChIP-Seq            62    0       0       0     0      0                   0
# OTHER                0    0       0       0     0     40                   0
# RNA-Seq              0    0      21       7    40      0                  53
# WGS                  0    0      31       0     0      0                   0
# ncRNA-Seq            0    0       0       0     0      0                 135
#
# LibrarySelection  unspecified
# LibraryStrategy
# AMPLICON                    0
# ChIP-Seq                    0
# OTHER                       0
# RNA-Seq                    32
# WGS                        12
# ncRNA-Seq                   0

# %%
# avoid the single cells and use only bulk for now
pd.crosstab(df["LibrarySource"], df["LibrarySelection"])
# Out:
# LibrarySelection            ChIP  PCR  RANDOM  RT-PCR  cDNA  other  \
# LibrarySource
# GENOMIC                       62    0      31       0     0     40
# METAGENOMIC                    0  671       0       0     0      0
# OTHER                          0   68       0       0     0      0
# TRANSCRIPTOMIC                 0    0      12       7    40      0
# TRANSCRIPTOMIC SINGLE CELL     0    0       9       0     0      0
#
# LibrarySelection            size fractionation  unspecified
# LibrarySource
# GENOMIC                                      0           12
# METAGENOMIC                                  0            0
# OTHER                                        0            0
# TRANSCRIPTOMIC                             188           32
# TRANSCRIPTOMIC SINGLE CELL                   0            0

# %%
selected_ENA_experiments = df.loc[
    (df["LibrarySelection"] == "RANDOM")
    & (df["LibrarySource"].isin(["GENOMIC", "TRANSCRIPTOMIC"]))
    & (df["Sequencer"].str.contains("Illumina"))
]

# %%
selected_ENA_experiments[["Sequencer", "LibrarySource"]].value_counts()
# Out:
# Sequencer                    LibrarySource
# Illumina HiSeq 2000          GENOMIC           13
# Illumina HiSeq 4000          TRANSCRIPTOMIC    12
# Illumina NovaSeq 6000        GENOMIC           11
# Illumina Genome Analyzer II  GENOMIC            4
# Illumina HiSeq 1000          GENOMIC            1
# Illumina HiSeq 3000          GENOMIC            1
# Name: count, dtype: int64

# %%
selected_ENA_experiments
# Out:
#        Experiment LibraryStrategy LibrarySelection   LibrarySource  \
# 0       ERX015104             WGS           RANDOM         GENOMIC
# 1       ERX015105             WGS           RANDOM         GENOMIC
# 2       ERX015106             WGS           RANDOM         GENOMIC
# 3       ERX044035             WGS           RANDOM         GENOMIC
# 4       ERX044036             WGS           RANDOM         GENOMIC
# 5       ERX046218             WGS           RANDOM         GENOMIC
# 6       ERX087586             WGS           RANDOM         GENOMIC
# 7       ERX092220             WGS           RANDOM         GENOMIC
# 15      ERX284224             WGS           RANDOM         GENOMIC
# 17      SRX039003             WGS           RANDOM         GENOMIC
# 18      SRX039004             WGS           RANDOM         GENOMIC
# 120     SRX114622             WGS           RANDOM         GENOMIC
# 121     SRX114623             WGS           RANDOM         GENOMIC
# 122     SRX114624             WGS           RANDOM         GENOMIC
# 123     SRX114625             WGS           RANDOM         GENOMIC
# 124     SRX114626             WGS           RANDOM         GENOMIC
# 125     SRX114627             WGS           RANDOM         GENOMIC
# 126     SRX114628             WGS           RANDOM         GENOMIC
# 133   SRX12232650         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# 134   SRX12232651         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# 135   SRX12232652         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# 136   SRX12232653         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# 137   SRX12232654         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# 138   SRX12232655         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# 139   SRX12232656         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# 140   SRX12232657         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# 141   SRX12232658         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# 142   SRX12232659         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# 143   SRX12232660         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# 144   SRX12232661         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# 897   SRX13646383             WGS           RANDOM         GENOMIC
# 1161  SRX23990783             WGS           RANDOM         GENOMIC
# 1162  SRX23990784             WGS           RANDOM         GENOMIC
# 1163  SRX23990785             WGS           RANDOM         GENOMIC
# 1164  SRX23990786             WGS           RANDOM         GENOMIC
# 1165  SRX23990787             WGS           RANDOM         GENOMIC
# 1166  SRX23990788             WGS           RANDOM         GENOMIC
# 1167  SRX23990789             WGS           RANDOM         GENOMIC
# 1168  SRX23990790             WGS           RANDOM         GENOMIC
# 1169  SRX23990791             WGS           RANDOM         GENOMIC
# 1170  SRX23990792             WGS           RANDOM         GENOMIC
# 1171  SRX23990793             WGS           RANDOM         GENOMIC
#
#      LibraryLayout LibraryProtocol                    Sequencer    StudyId  \
# 0           PAIRED          No PCR  Illumina Genome Analyzer II  ERP000532
# 1           PAIRED          No PCR  Illumina Genome Analyzer II  ERP000532
# 2           PAIRED          No PCR          Illumina HiSeq 2000  ERP000532
# 3           PAIRED          No PCR          Illumina HiSeq 2000  ERP000904
# 4           PAIRED          No PCR          Illumina HiSeq 2000  ERP000904
# 5           PAIRED      Long range          Illumina HiSeq 2000  ERP000904
# 6           PAIRED          No PCR          Illumina HiSeq 2000  ERP000904
# 7           PAIRED      Long range          Illumina HiSeq 2000  ERP000904
# 15          PAIRED          Custom          Illumina HiSeq 2000  ERP000904
# 17          PAIRED            None  Illumina Genome Analyzer II  SRP005397
# 18          PAIRED            None  Illumina Genome Analyzer II  SRP005397
# 120         PAIRED            None          Illumina HiSeq 1000  SRP010159
# 121         PAIRED            None          Illumina HiSeq 2000  SRP010159
# 122         PAIRED            None          Illumina HiSeq 2000  SRP010159
# 123         PAIRED            None          Illumina HiSeq 2000  SRP010159
# 124         PAIRED            None          Illumina HiSeq 2000  SRP010159
# 125         PAIRED            None          Illumina HiSeq 2000  SRP010159
# 126         PAIRED            None          Illumina HiSeq 2000  SRP010159
# 133         PAIRED            None          Illumina HiSeq 4000  SRP013609
# 134         PAIRED            None          Illumina HiSeq 4000  SRP013609
# 135         PAIRED            None          Illumina HiSeq 4000  SRP013609
# 136         PAIRED            None          Illumina HiSeq 4000  SRP013609
# 137         PAIRED            None          Illumina HiSeq 4000  SRP013609
# 138         PAIRED            None          Illumina HiSeq 4000  SRP013609
# 139         PAIRED            None          Illumina HiSeq 4000  SRP013609
# 140         PAIRED            None          Illumina HiSeq 4000  SRP013609
# 141         PAIRED            None          Illumina HiSeq 4000  SRP013609
# 142         PAIRED            None          Illumina HiSeq 4000  SRP013609
# 143         PAIRED            None          Illumina HiSeq 4000  SRP013609
# 144         PAIRED            None          Illumina HiSeq 4000  SRP013609
# 897         PAIRED            None          Illumina HiSeq 3000  SRP353851
# 1161        PAIRED            None        Illumina NovaSeq 6000  SRP493604
# 1162        PAIRED            None        Illumina NovaSeq 6000  SRP493604
# 1163        PAIRED            None        Illumina NovaSeq 6000  SRP493604
# 1164        PAIRED            None        Illumina NovaSeq 6000  SRP493604
# 1165        PAIRED            None        Illumina NovaSeq 6000  SRP493604
# 1166        PAIRED            None        Illumina NovaSeq 6000  SRP493604
# 1167        PAIRED            None        Illumina NovaSeq 6000  SRP493604
# 1168        PAIRED            None        Illumina NovaSeq 6000  SRP493604
# 1169        PAIRED            None        Illumina NovaSeq 6000  SRP493604
# 1170        PAIRED            None        Illumina NovaSeq 6000  SRP493604
# 1171        PAIRED            None        Illumina NovaSeq 6000  SRP493604
#
#          SampleId     BioSample
# 0       ERS006615   SAMEA915801
# 1       ERS006615   SAMEA915801
# 2       ERS006615   SAMEA915801
# 3       ERS056112  SAMEA1034744
# 4       ERS056111  SAMEA1034755
# 5       ERS067638  SAMEA1034750
# 6       ERS083920  SAMEA1463534
# 7       ERS094834  SAMEA1463511
# 15      ERS083922  SAMEA1984308
# 17      SRS155755          None
# 18      SRS155756          None
# 120     SRS285000          None
# 121     SRS285000          None
# 122     SRS285000          None
# 123     SRS285000          None
# 124     SRS285000          None
# 125     SRS285000          None
# 126     SRS285000          None
# 133   SRS10208336          None
# 134   SRS10208337          None
# 135   SRS10208338          None
# 136   SRS10208339          None
# 137   SRS10208340          None
# 138   SRS10208341          None
# 139   SRS10208342          None
# 140   SRS10208345          None
# 141   SRS10208344          None
# 142   SRS10208343          None
# 143   SRS10208346          None
# 144   SRS10208347          None
# 897   SRS11532834  SAMN24665689
# 1161  SRS20787929          None
# 1162  SRS20787929          None
# 1163  SRS20787929          None
# 1164  SRS20787929          None
# 1165  SRS20787929          None
# 1166  SRS20787929          None
# 1167  SRS20787929          None
# 1168  SRS20787929          None
# 1169  SRS20787929          None
# 1170  SRS20787929          None
# 1171  SRS20787929          None
